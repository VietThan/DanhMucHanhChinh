# %%
import requests
from datetime import date, datetime
import xmltodict
import json

# %%
today = datetime.today()
today_string = datetime.strftime(today, '%d-%m-%Y')

URL = 'https://danhmuchanhchinh.gso.gov.vn/DMDVHC.asmx?wsdl'

# %%
DISTRICT_HEADERS = {
    'Content-Type': 'text/xml',
    'SOAPAction': "http://tempuri.org/DanhMucQuanHuyen"
} 

DISTRICT_BODY = (''
'<?xml version="1.0" encoding="utf-8"?>'
'<soap:Envelope xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/">'
'  <soap:Body>'
'    <DanhMucQuanHuyen xmlns="http://tempuri.org/">'
f'      <DenNgay>{today_string}</DenNgay>'
#'      <Tinh>27</Tinh>'
#'      <TenTinh>Tỉnh Hải Dương</TenTinh>'
'    </DanhMucQuanHuyen>'
'  </soap:Body>'
'</soap:Envelope>'
)

# %%
def return_value_with_key(root : dict, key: str):
    result = None
    
    if type(root) is not dict:
        return result
    
    for k, v in root.items():
        if k == key:
            return v
        else:
            result = return_value_with_key(v, key=key)
            if result is not None:
                return result
    return result


def get_danhmuchanhchinh_response(
    body : str,
    headers : str,
    url : str = URL
) -> requests.Response:
    """
    Retrieve utf-8 decoded content of response from DanhMucHanhChinh API
    based on passed-in body and header post.
    """

    try:
        response = requests.post(url,data=body,headers=headers)
    except Exception as e:
        print(f"error {e} in get_province()")
    else:
        return response.content.decode("utf-8")

def get_everything():
    """
    Get the most complete responses from DanhMucHanhChinh API for 
    all administrative subdivisions. parse response and save content
    into json format.
    """
    # get province
    # province_content = get_danhmuchanhchinh_response(PROVINCE_BODY, PROVINCE_HEADERS)
    # provinces = parse_province_content(province_content)
    # with open('provinces.json', 'w', encoding='utf8') as provinces_json_name:
    #     json.dump(provinces, provinces_json_name, ensure_ascii=False, indent=4)

    
    # # get district
    # district_content = get_danhmuchanhchinh_response(DISTRICT_BODY, DISTRICT_HEADERS)
    # districts = parse_district_content(province_content)
    
    # # get wards
    # ward_content = get_danhmuchanhchinh_response(WARD_BODY, WARD_HEADERS)
    # wards = parse_ward_content(province_content)
    return 0

# %%
district_content = get_danhmuchanhchinh_response(DISTRICT_BODY, DISTRICT_HEADERS)
district_content
# Out:
# '<?xml version="1.0" encoding="utf-8"?><soap:Envelope xmlns:soap="http://schemas.xmlsoap.org/soap/envelope/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema"><soap:Body><DanhMucQuanHuyenResponse xmlns="http://tempuri.org/"><DanhMucQuanHuyenResult><xs:schema id="NewDataSet" xmlns="" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:msdata="urn:schemas-microsoft-com:xml-msdata"><xs:element name="NewDataSet" msdata:IsDataSet="true" msdata:MainDataTable="TABLE" msdata:UseCurrentLocale="true"><xs:complexType><xs:choice minOccurs="0" maxOccurs="unbounded"><xs:element name="TABLE"><xs:complexType><xs:sequence><xs:element name="MaTinh" type="xs:string" minOccurs="0" /><xs:element name="TenTinh" type="xs:string" minOccurs="0" /><xs:element name="MaQuanHuyen" type="xs:string" minOccurs="0" /><xs:element name="TenQuanHuyen" type="xs:string" minOccurs="0" /><xs:element name="LoaiHinh" type="xs:string" minOccurs="0" /><xs:element name="LoaiDoThi" type="xs:string" minOccurs="0" /><xs:element name="Vung" type="xs:string" minOccurs="0" /></xs:sequence></xs:complexType></xs:element></xs:choice></xs:complexType></xs:element></xs:schema><diffgr:diffgram xmlns:msdata="urn:schemas-microsoft-com:xml-msdata" xmlns:diffgr="urn:schemas-microsoft-com:xml-diffgram-v1"><DocumentElement xmlns=""><TABLE diffgr:id="TABLE1" msdata:rowOrder="0"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>001</MaQuanHuyen><TenQuanHuyen>Quận Ba Đình</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE2" msdata:rowOrder="1"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>002</MaQuanHuyen><TenQuanHuyen>Quận Hoàn Kiếm</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE3" msdata:rowOrder="2"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>003</MaQuanHuyen><TenQuanHuyen>Quận Tây Hồ</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE4" msdata:rowOrder="3"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>004</MaQuanHuyen><TenQuanHuyen>Quận Long Biên</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE5" msdata:rowOrder="4"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>005</MaQuanHuyen><TenQuanHuyen>Quận Cầu Giấy</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE6" msdata:rowOrder="5"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>006</MaQuanHuyen><TenQuanHuyen>Quận Đống Đa</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE7" msdata:rowOrder="6"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>007</MaQuanHuyen><TenQuanHuyen>Quận Hai Bà Trưng</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE8" msdata:rowOrder="7"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>008</MaQuanHuyen><TenQuanHuyen>Quận Hoàng Mai</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE9" msdata:rowOrder="8"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>009</MaQuanHuyen><TenQuanHuyen>Quận Thanh Xuân</TenQuanHuyen><LoaiHinh>Quận</LoaiHinh></TABLE><TABLE diffgr:id="TABLE10" msdata:rowOrder="9"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>016</MaQuanHuyen><TenQuanHuyen>Huyện Sóc Sơn</TenQuanHuyen><LoaiHinh>Huyện</LoaiHinh></TABLE><TABLE diffgr:id="TABLE11" msdata:rowOrder="10"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>017</MaQuanHuyen><TenQuanHuyen>Huyện Đông Anh</TenQuanHuyen><LoaiHinh>Huyện</LoaiHinh></TABLE><TABLE diffgr:id="TABLE12" msdata:rowOrder="11"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>018</MaQuanHuyen><TenQuanHuyen>Huyện Gia Lâm</TenQuanHuyen><LoaiHinh>Huyện</LoaiHinh></TABLE><TABLE diffgr:id="TABLE13" msdata:rowOrder="12"><MaTinh>01</MaTinh><TenTinh>Thành phố Hà Nội</TenTinh><MaQuanHuyen>019</MaQuanHuyen><TenQuanHuyen>Quận Nam Từ Liêm</TenQuanHuyen><LoaiHinh>Q ...

# %%
def parse_district_content(district_content):
    district_content_dict = xmltodict.parse(district_content)
    district_dict = return_value_with_key(root=district_content_dict, key='TABLE')

    districts = []
    for item in district_dict:
        district = {}

        keys = ("MaTinh", "TenTinh", "MaQuanHuyen", "TenQuanHuyen", "LoaiHinh", "@msdata:rowOrder", "@diffgr:id")
        for key in item:
            if key not in keys:
                print(f"found weird key: {key}")
                print(f"    with values: {item[key]}")

        district["province_service_key"] = item["MaTinh"]
        district["province_name"] = item["TenTinh"]
        district["district_service_key"] = item["MaQuanHuyen"]
        district["name"] = item["TenQuanHuyen"]
        district["type"] = item["LoaiHinh"]
        district["province_service_order"] = item["@msdata:rowOrder"]
    
        districts.append(district)
        
    return districts

# %%
districts = parse_district_content(district_content)
districts
# Out:
# [{'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '001',
#   'name': 'Quận Ba Đình',
#   'type': 'Quận',
#   'province_service_order': '0'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '002',
#   'name': 'Quận Hoàn Kiếm',
#   'type': 'Quận',
#   'province_service_order': '1'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '003',
#   'name': 'Quận Tây Hồ',
#   'type': 'Quận',
#   'province_service_order': '2'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '004',
#   'name': 'Quận Long Biên',
#   'type': 'Quận',
#   'province_service_order': '3'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '005',
#   'name': 'Quận Cầu Giấy',
#   'type': 'Quận',
#   'province_service_order': '4'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '006',
#   'name': 'Quận Đống Đa',
#   'type': 'Quận',
#   'province_service_order': '5'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '007',
#   'name': 'Quận Hai Bà Trưng',
#   'type': 'Quận',
#   'province_service_order': '6'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '008',
#   'name': 'Quận Hoàng Mai',
#   'type': 'Quận',
#   'province_service_order': '7'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '009',
#   'name': 'Quận Thanh Xuân',
#   'type': 'Quận',
#   'province_service_order': '8'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '016',
#   'name': 'Huyện Sóc Sơn',
#   'type': 'Huyện',
#   'province_service_order': '9'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '017',
#   'name': 'Huyện Đông Anh',
#   'type': 'Huyện',
#   'province_service_order': '10'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '018',
#   'name': 'Huyện Gia Lâm',
#   'type': 'Huyện',
#   'province_service_order': '11'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '019',
#   'name': 'Quận Nam Từ Liêm',
#   'type': 'Quận',
#   'province_service_order': '12'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '020',
#   'name': 'Huyện Thanh Trì',
#   'type': 'Huyện',
#   'province_service_order': '13'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '021',
#   'name': 'Quận Bắc Từ Liêm',
#   'type': 'Quận',
#   'province_service_order': '14'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '250',
#   'name': 'Huyện Mê Linh',
#   'type': 'Huyện',
#   'province_service_order': '15'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '268',
#   'name': 'Quận Hà Đông',
#   'type': 'Quận',
#   'province_service_order': '16'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '269',
#   'name': 'Thị xã Sơn Tây',
#   'type': 'Thị xã',
#   'province_service_order': '17'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '271',
#   'name': 'Huyện Ba Vì',
#   'type': 'Huyện',
#   'province_service_order': '18'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '272',
#   'name': 'Huyện Phúc Thọ',
#   'type': 'Huyện',
#   'province_service_order': '19'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '273',
#   'name': 'Huyện Đan Phượng',
#   'type': 'Huyện',
#   'province_service_order': '20'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '274',
#   'name': 'Huyện Hoài Đức',
#   'type': 'Huyện',
#   'province_service_order': '21'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '275',
#   'name': 'Huyện Quốc Oai',
#   'type': 'Huyện',
#   'province_service_order': '22'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '276',
#   'name': 'Huyện Thạch Thất',
#   'type': 'Huyện',
#   'province_service_order': '23'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '277',
#   'name': 'Huyện Chương Mỹ',
#   'type': 'Huyện',
#   'province_service_order': '24'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '278',
#   'name': 'Huyện Thanh Oai',
#   'type': 'Huyện',
#   'province_service_order': '25'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '279',
#   'name': 'Huyện Thường Tín',
#   'type': 'Huyện',
#   'province_service_order': '26'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '280',
#   'name': 'Huyện Phú Xuyên',
#   'type': 'Huyện',
#   'province_service_order': '27'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '281',
#   'name': 'Huyện Ứng Hòa',
#   'type': 'Huyện',
#   'province_service_order': '28'},
#  {'province_service_key': '01',
#   'province_name': 'Thành phố Hà Nội',
#   'district_service_key': '282',
#   'name': 'Huyện Mỹ Đức',
#   'type': 'Huyện',
#   'province_service_order': '29'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '024',
#   'name': 'Thành phố Hà Giang',
#   'type': 'Thành phố',
#   'province_service_order': '30'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '026',
#   'name': 'Huyện Đồng Văn',
#   'type': 'Huyện',
#   'province_service_order': '31'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '027',
#   'name': 'Huyện Mèo Vạc',
#   'type': 'Huyện',
#   'province_service_order': '32'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '028',
#   'name': 'Huyện Yên Minh',
#   'type': 'Huyện',
#   'province_service_order': '33'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '029',
#   'name': 'Huyện Quản Bạ',
#   'type': 'Huyện',
#   'province_service_order': '34'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '030',
#   'name': 'Huyện Vị Xuyên',
#   'type': 'Huyện',
#   'province_service_order': '35'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '031',
#   'name': 'Huyện Bắc Mê',
#   'type': 'Huyện',
#   'province_service_order': '36'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '032',
#   'name': 'Huyện Hoàng Su Phì',
#   'type': 'Huyện',
#   'province_service_order': '37'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '033',
#   'name': 'Huyện Xín Mần',
#   'type': 'Huyện',
#   'province_service_order': '38'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '034',
#   'name': 'Huyện Bắc Quang',
#   'type': 'Huyện',
#   'province_service_order': '39'},
#  {'province_service_key': '02',
#   'province_name': 'Tỉnh Hà Giang',
#   'district_service_key': '035',
#   'name': 'Huyện Quang Bình',
#   'type': 'Huyện',
#   'province_service_order': '40'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '040',
#   'name': 'Thành phố Cao Bằng',
#   'type': 'Thành phố',
#   'province_service_order': '41'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '042',
#   'name': 'Huyện Bảo Lâm',
#   'type': 'Huyện',
#   'province_service_order': '42'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '043',
#   'name': 'Huyện Bảo Lạc',
#   'type': 'Huyện',
#   'province_service_order': '43'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '045',
#   'name': 'Huyện Hà Quảng',
#   'type': 'Huyện',
#   'province_service_order': '44'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '047',
#   'name': 'Huyện Trùng Khánh',
#   'type': 'Huyện',
#   'province_service_order': '45'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '048',
#   'name': 'Huyện Hạ Lang',
#   'type': 'Huyện',
#   'province_service_order': '46'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '049',
#   'name': 'Huyện Quảng Hòa',
#   'type': 'Huyện',
#   'province_service_order': '47'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '051',
#   'name': 'Huyện Hoà An',
#   'type': 'Huyện',
#   'province_service_order': '48'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '052',
#   'name': 'Huyện Nguyên Bình',
#   'type': 'Huyện',
#   'province_service_order': '49'},
#  {'province_service_key': '04',
#   'province_name': 'Tỉnh Cao Bằng',
#   'district_service_key': '053',
#   'name': 'Huyện Thạch An',
#   'type': 'Huyện',
#   'province_service_order': '50'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '058',
#   'name': 'Thành Phố Bắc Kạn',
#   'type': 'Thành phố',
#   'province_service_order': '51'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '060',
#   'name': 'Huyện Pác Nặm',
#   'type': 'Huyện',
#   'province_service_order': '52'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '061',
#   'name': 'Huyện Ba Bể',
#   'type': 'Huyện',
#   'province_service_order': '53'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '062',
#   'name': 'Huyện Ngân Sơn',
#   'type': 'Huyện',
#   'province_service_order': '54'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '063',
#   'name': 'Huyện Bạch Thông',
#   'type': 'Huyện',
#   'province_service_order': '55'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '064',
#   'name': 'Huyện Chợ Đồn',
#   'type': 'Huyện',
#   'province_service_order': '56'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '065',
#   'name': 'Huyện Chợ Mới',
#   'type': 'Huyện',
#   'province_service_order': '57'},
#  {'province_service_key': '06',
#   'province_name': 'Tỉnh Bắc Kạn',
#   'district_service_key': '066',
#   'name': 'Huyện Na Rì',
#   'type': 'Huyện',
#   'province_service_order': '58'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '070',
#   'name': 'Thành phố Tuyên Quang',
#   'type': 'Thành phố',
#   'province_service_order': '59'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '071',
#   'name': 'Huyện Lâm Bình',
#   'type': 'Huyện',
#   'province_service_order': '60'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '072',
#   'name': 'Huyện Na Hang',
#   'type': 'Huyện',
#   'province_service_order': '61'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '073',
#   'name': 'Huyện Chiêm Hóa',
#   'type': 'Huyện',
#   'province_service_order': '62'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '074',
#   'name': 'Huyện Hàm Yên',
#   'type': 'Huyện',
#   'province_service_order': '63'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '075',
#   'name': 'Huyện Yên Sơn',
#   'type': 'Huyện',
#   'province_service_order': '64'},
#  {'province_service_key': '08',
#   'province_name': 'Tỉnh Tuyên Quang',
#   'district_service_key': '076',
#   'name': 'Huyện Sơn Dương',
#   'type': 'Huyện',
#   'province_service_order': '65'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '080',
#   'name': 'Thành phố Lào Cai',
#   'type': 'Thành phố',
#   'province_service_order': '66'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '082',
#   'name': 'Huyện Bát Xát',
#   'type': 'Huyện',
#   'province_service_order': '67'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '083',
#   'name': 'Huyện Mường Khương',
#   'type': 'Huyện',
#   'province_service_order': '68'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '084',
#   'name': 'Huyện Si Ma Cai',
#   'type': 'Huyện',
#   'province_service_order': '69'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '085',
#   'name': 'Huyện Bắc Hà',
#   'type': 'Huyện',
#   'province_service_order': '70'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '086',
#   'name': 'Huyện Bảo Thắng',
#   'type': 'Huyện',
#   'province_service_order': '71'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '087',
#   'name': 'Huyện Bảo Yên',
#   'type': 'Huyện',
#   'province_service_order': '72'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '088',
#   'name': 'Thị xã Sa Pa',
#   'type': 'Thị xã',
#   'province_service_order': '73'},
#  {'province_service_key': '10',
#   'province_name': 'Tỉnh Lào Cai',
#   'district_service_key': '089',
#   'name': 'Huyện Văn Bàn',
#   'type': 'Huyện',
#   'province_service_order': '74'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '094',
#   'name': 'Thành phố Điện Biên Phủ',
#   'type': 'Thành phố',
#   'province_service_order': '75'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '095',
#   'name': 'Thị Xã Mường Lay',
#   'type': 'Thị xã',
#   'province_service_order': '76'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '096',
#   'name': 'Huyện Mường Nhé',
#   'type': 'Huyện',
#   'province_service_order': '77'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '097',
#   'name': 'Huyện Mường Chà',
#   'type': 'Huyện',
#   'province_service_order': '78'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '098',
#   'name': 'Huyện Tủa Chùa',
#   'type': 'Huyện',
#   'province_service_order': '79'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '099',
#   'name': 'Huyện Tuần Giáo',
#   'type': 'Huyện',
#   'province_service_order': '80'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '100',
#   'name': 'Huyện Điện Biên',
#   'type': 'Huyện',
#   'province_service_order': '81'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '101',
#   'name': 'Huyện Điện Biên Đông',
#   'type': 'Huyện',
#   'province_service_order': '82'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '102',
#   'name': 'Huyện Mường Ảng',
#   'type': 'Huyện',
#   'province_service_order': '83'},
#  {'province_service_key': '11',
#   'province_name': 'Tỉnh Điện Biên',
#   'district_service_key': '103',
#   'name': 'Huyện Nậm Pồ',
#   'type': 'Huyện',
#   'province_service_order': '84'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '105',
#   'name': 'Thành phố Lai Châu',
#   'type': 'Thành phố',
#   'province_service_order': '85'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '106',
#   'name': 'Huyện Tam Đường',
#   'type': 'Huyện',
#   'province_service_order': '86'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '107',
#   'name': 'Huyện Mường Tè',
#   'type': 'Huyện',
#   'province_service_order': '87'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '108',
#   'name': 'Huyện Sìn Hồ',
#   'type': 'Huyện',
#   'province_service_order': '88'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '109',
#   'name': 'Huyện Phong Thổ',
#   'type': 'Huyện',
#   'province_service_order': '89'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '110',
#   'name': 'Huyện Than Uyên',
#   'type': 'Huyện',
#   'province_service_order': '90'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '111',
#   'name': 'Huyện Tân Uyên',
#   'type': 'Huyện',
#   'province_service_order': '91'},
#  {'province_service_key': '12',
#   'province_name': 'Tỉnh Lai Châu',
#   'district_service_key': '112',
#   'name': 'Huyện Nậm Nhùn',
#   'type': 'Huyện',
#   'province_service_order': '92'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '116',
#   'name': 'Thành phố Sơn La',
#   'type': 'Thành phố',
#   'province_service_order': '93'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '118',
#   'name': 'Huyện Quỳnh Nhai',
#   'type': 'Huyện',
#   'province_service_order': '94'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '119',
#   'name': 'Huyện Thuận Châu',
#   'type': 'Huyện',
#   'province_service_order': '95'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '120',
#   'name': 'Huyện Mường La',
#   'type': 'Huyện',
#   'province_service_order': '96'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '121',
#   'name': 'Huyện Bắc Yên',
#   'type': 'Huyện',
#   'province_service_order': '97'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '122',
#   'name': 'Huyện Phù Yên',
#   'type': 'Huyện',
#   'province_service_order': '98'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '123',
#   'name': 'Huyện Mộc Châu',
#   'type': 'Huyện',
#   'province_service_order': '99'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '124',
#   'name': 'Huyện Yên Châu',
#   'type': 'Huyện',
#   'province_service_order': '100'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '125',
#   'name': 'Huyện Mai Sơn',
#   'type': 'Huyện',
#   'province_service_order': '101'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '126',
#   'name': 'Huyện Sông Mã',
#   'type': 'Huyện',
#   'province_service_order': '102'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '127',
#   'name': 'Huyện Sốp Cộp',
#   'type': 'Huyện',
#   'province_service_order': '103'},
#  {'province_service_key': '14',
#   'province_name': 'Tỉnh Sơn La',
#   'district_service_key': '128',
#   'name': 'Huyện Vân Hồ',
#   'type': 'Huyện',
#   'province_service_order': '104'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '132',
#   'name': 'Thành phố Yên Bái',
#   'type': 'Thành phố',
#   'province_service_order': '105'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '133',
#   'name': 'Thị xã Nghĩa Lộ',
#   'type': 'Thị xã',
#   'province_service_order': '106'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '135',
#   'name': 'Huyện Lục Yên',
#   'type': 'Huyện',
#   'province_service_order': '107'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '136',
#   'name': 'Huyện Văn Yên',
#   'type': 'Huyện',
#   'province_service_order': '108'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '137',
#   'name': 'Huyện Mù Căng Chải',
#   'type': 'Huyện',
#   'province_service_order': '109'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '138',
#   'name': 'Huyện Trấn Yên',
#   'type': 'Huyện',
#   'province_service_order': '110'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '139',
#   'name': 'Huyện Trạm Tấu',
#   'type': 'Huyện',
#   'province_service_order': '111'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '140',
#   'name': 'Huyện Văn Chấn',
#   'type': 'Huyện',
#   'province_service_order': '112'},
#  {'province_service_key': '15',
#   'province_name': 'Tỉnh Yên Bái',
#   'district_service_key': '141',
#   'name': 'Huyện Yên Bình',
#   'type': 'Huyện',
#   'province_service_order': '113'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '148',
#   'name': 'Thành phố Hòa Bình',
#   'type': 'Thành phố',
#   'province_service_order': '114'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '150',
#   'name': 'Huyện Đà Bắc',
#   'type': 'Huyện',
#   'province_service_order': '115'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '152',
#   'name': 'Huyện Lương Sơn',
#   'type': 'Huyện',
#   'province_service_order': '116'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '153',
#   'name': 'Huyện Kim Bôi',
#   'type': 'Huyện',
#   'province_service_order': '117'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '154',
#   'name': 'Huyện Cao Phong',
#   'type': 'Huyện',
#   'province_service_order': '118'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '155',
#   'name': 'Huyện Tân Lạc',
#   'type': 'Huyện',
#   'province_service_order': '119'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '156',
#   'name': 'Huyện Mai Châu',
#   'type': 'Huyện',
#   'province_service_order': '120'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '157',
#   'name': 'Huyện Lạc Sơn',
#   'type': 'Huyện',
#   'province_service_order': '121'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '158',
#   'name': 'Huyện Yên Thủy',
#   'type': 'Huyện',
#   'province_service_order': '122'},
#  {'province_service_key': '17',
#   'province_name': 'Tỉnh Hoà Bình',
#   'district_service_key': '159',
#   'name': 'Huyện Lạc Thủy',
#   'type': 'Huyện',
#   'province_service_order': '123'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '164',
#   'name': 'Thành phố Thái Nguyên',
#   'type': 'Thành phố',
#   'province_service_order': '124'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '165',
#   'name': 'Thành phố Sông Công',
#   'type': 'Thành phố',
#   'province_service_order': '125'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '167',
#   'name': 'Huyện Định Hóa',
#   'type': 'Huyện',
#   'province_service_order': '126'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '168',
#   'name': 'Huyện Phú Lương',
#   'type': 'Huyện',
#   'province_service_order': '127'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '169',
#   'name': 'Huyện Đồng Hỷ',
#   'type': 'Huyện',
#   'province_service_order': '128'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '170',
#   'name': 'Huyện Võ Nhai',
#   'type': 'Huyện',
#   'province_service_order': '129'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '171',
#   'name': 'Huyện Đại Từ',
#   'type': 'Huyện',
#   'province_service_order': '130'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '172',
#   'name': 'Thành phố Phổ Yên',
#   'type': 'Thành phố',
#   'province_service_order': '131'},
#  {'province_service_key': '19',
#   'province_name': 'Tỉnh Thái Nguyên',
#   'district_service_key': '173',
#   'name': 'Huyện Phú Bình',
#   'type': 'Huyện',
#   'province_service_order': '132'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '178',
#   'name': 'Thành phố Lạng Sơn',
#   'type': 'Thành phố',
#   'province_service_order': '133'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '180',
#   'name': 'Huyện Tràng Định',
#   'type': 'Huyện',
#   'province_service_order': '134'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '181',
#   'name': 'Huyện Bình Gia',
#   'type': 'Huyện',
#   'province_service_order': '135'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '182',
#   'name': 'Huyện Văn Lãng',
#   'type': 'Huyện',
#   'province_service_order': '136'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '183',
#   'name': 'Huyện Cao Lộc',
#   'type': 'Huyện',
#   'province_service_order': '137'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '184',
#   'name': 'Huyện Văn Quan',
#   'type': 'Huyện',
#   'province_service_order': '138'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '185',
#   'name': 'Huyện Bắc Sơn',
#   'type': 'Huyện',
#   'province_service_order': '139'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '186',
#   'name': 'Huyện Hữu Lũng',
#   'type': 'Huyện',
#   'province_service_order': '140'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '187',
#   'name': 'Huyện Chi Lăng',
#   'type': 'Huyện',
#   'province_service_order': '141'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '188',
#   'name': 'Huyện Lộc Bình',
#   'type': 'Huyện',
#   'province_service_order': '142'},
#  {'province_service_key': '20',
#   'province_name': 'Tỉnh Lạng Sơn',
#   'district_service_key': '189',
#   'name': 'Huyện Đình Lập',
#   'type': 'Huyện',
#   'province_service_order': '143'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '193',
#   'name': 'Thành phố Hạ Long',
#   'type': 'Thành phố',
#   'province_service_order': '144'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '194',
#   'name': 'Thành phố Móng Cái',
#   'type': 'Thành phố',
#   'province_service_order': '145'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '195',
#   'name': 'Thành phố Cẩm Phả',
#   'type': 'Thành phố',
#   'province_service_order': '146'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '196',
#   'name': 'Thành phố Uông Bí',
#   'type': 'Thành phố',
#   'province_service_order': '147'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '198',
#   'name': 'Huyện Bình Liêu',
#   'type': 'Huyện',
#   'province_service_order': '148'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '199',
#   'name': 'Huyện Tiên Yên',
#   'type': 'Huyện',
#   'province_service_order': '149'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '200',
#   'name': 'Huyện Đầm Hà',
#   'type': 'Huyện',
#   'province_service_order': '150'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '201',
#   'name': 'Huyện Hải Hà',
#   'type': 'Huyện',
#   'province_service_order': '151'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '202',
#   'name': 'Huyện Ba Chẽ',
#   'type': 'Huyện',
#   'province_service_order': '152'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '203',
#   'name': 'Huyện Vân Đồn',
#   'type': 'Huyện',
#   'province_service_order': '153'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '205',
#   'name': 'Thị xã Đông Triều',
#   'type': 'Thị xã',
#   'province_service_order': '154'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '206',
#   'name': 'Thị xã Quảng Yên',
#   'type': 'Thị xã',
#   'province_service_order': '155'},
#  {'province_service_key': '22',
#   'province_name': 'Tỉnh Quảng Ninh',
#   'district_service_key': '207',
#   'name': 'Huyện Cô Tô',
#   'type': 'Huyện',
#   'province_service_order': '156'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '213',
#   'name': 'Thành phố Bắc Giang',
#   'type': 'Thành phố',
#   'province_service_order': '157'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '215',
#   'name': 'Huyện Yên Thế',
#   'type': 'Huyện',
#   'province_service_order': '158'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '216',
#   'name': 'Huyện Tân Yên',
#   'type': 'Huyện',
#   'province_service_order': '159'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '217',
#   'name': 'Huyện Lạng Giang',
#   'type': 'Huyện',
#   'province_service_order': '160'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '218',
#   'name': 'Huyện Lục Nam',
#   'type': 'Huyện',
#   'province_service_order': '161'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '219',
#   'name': 'Huyện Lục Ngạn',
#   'type': 'Huyện',
#   'province_service_order': '162'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '220',
#   'name': 'Huyện Sơn Động',
#   'type': 'Huyện',
#   'province_service_order': '163'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '221',
#   'name': 'Huyện Yên Dũng',
#   'type': 'Huyện',
#   'province_service_order': '164'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '222',
#   'name': 'Huyện Việt Yên',
#   'type': 'Huyện',
#   'province_service_order': '165'},
#  {'province_service_key': '24',
#   'province_name': 'Tỉnh Bắc Giang',
#   'district_service_key': '223',
#   'name': 'Huyện Hiệp Hòa',
#   'type': 'Huyện',
#   'province_service_order': '166'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '227',
#   'name': 'Thành phố Việt Trì',
#   'type': 'Thành phố',
#   'province_service_order': '167'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '228',
#   'name': 'Thị xã Phú Thọ',
#   'type': 'Thị xã',
#   'province_service_order': '168'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '230',
#   'name': 'Huyện Đoan Hùng',
#   'type': 'Huyện',
#   'province_service_order': '169'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '231',
#   'name': 'Huyện Hạ Hoà',
#   'type': 'Huyện',
#   'province_service_order': '170'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '232',
#   'name': 'Huyện Thanh Ba',
#   'type': 'Huyện',
#   'province_service_order': '171'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '233',
#   'name': 'Huyện Phù Ninh',
#   'type': 'Huyện',
#   'province_service_order': '172'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '234',
#   'name': 'Huyện Yên Lập',
#   'type': 'Huyện',
#   'province_service_order': '173'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '235',
#   'name': 'Huyện Cẩm Khê',
#   'type': 'Huyện',
#   'province_service_order': '174'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '236',
#   'name': 'Huyện Tam Nông',
#   'type': 'Huyện',
#   'province_service_order': '175'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '237',
#   'name': 'Huyện Lâm Thao',
#   'type': 'Huyện',
#   'province_service_order': '176'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '238',
#   'name': 'Huyện Thanh Sơn',
#   'type': 'Huyện',
#   'province_service_order': '177'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '239',
#   'name': 'Huyện Thanh Thuỷ',
#   'type': 'Huyện',
#   'province_service_order': '178'},
#  {'province_service_key': '25',
#   'province_name': 'Tỉnh Phú Thọ',
#   'district_service_key': '240',
#   'name': 'Huyện Tân Sơn',
#   'type': 'Huyện',
#   'province_service_order': '179'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '243',
#   'name': 'Thành phố Vĩnh Yên',
#   'type': 'Thành phố',
#   'province_service_order': '180'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '244',
#   'name': 'Thành phố Phúc Yên',
#   'type': 'Thành phố',
#   'province_service_order': '181'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '246',
#   'name': 'Huyện Lập Thạch',
#   'type': 'Huyện',
#   'province_service_order': '182'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '247',
#   'name': 'Huyện Tam Dương',
#   'type': 'Huyện',
#   'province_service_order': '183'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '248',
#   'name': 'Huyện Tam Đảo',
#   'type': 'Huyện',
#   'province_service_order': '184'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '249',
#   'name': 'Huyện Bình Xuyên',
#   'type': 'Huyện',
#   'province_service_order': '185'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '251',
#   'name': 'Huyện Yên Lạc',
#   'type': 'Huyện',
#   'province_service_order': '186'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '252',
#   'name': 'Huyện Vĩnh Tường',
#   'type': 'Huyện',
#   'province_service_order': '187'},
#  {'province_service_key': '26',
#   'province_name': 'Tỉnh Vĩnh Phúc',
#   'district_service_key': '253',
#   'name': 'Huyện Sông Lô',
#   'type': 'Huyện',
#   'province_service_order': '188'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '256',
#   'name': 'Thành phố Bắc Ninh',
#   'type': 'Thành phố',
#   'province_service_order': '189'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '258',
#   'name': 'Huyện Yên Phong',
#   'type': 'Huyện',
#   'province_service_order': '190'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '259',
#   'name': 'Huyện Quế Võ',
#   'type': 'Huyện',
#   'province_service_order': '191'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '260',
#   'name': 'Huyện Tiên Du',
#   'type': 'Huyện',
#   'province_service_order': '192'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '261',
#   'name': 'Thành phố Từ Sơn',
#   'type': 'Thành phố',
#   'province_service_order': '193'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '262',
#   'name': 'Huyện Thuận Thành',
#   'type': 'Huyện',
#   'province_service_order': '194'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '263',
#   'name': 'Huyện Gia Bình',
#   'type': 'Huyện',
#   'province_service_order': '195'},
#  {'province_service_key': '27',
#   'province_name': 'Tỉnh Bắc Ninh',
#   'district_service_key': '264',
#   'name': 'Huyện Lương Tài',
#   'type': 'Huyện',
#   'province_service_order': '196'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '288',
#   'name': 'Thành phố Hải Dương',
#   'type': 'Thành phố',
#   'province_service_order': '197'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '290',
#   'name': 'Thành phố Chí Linh',
#   'type': 'Thành phố',
#   'province_service_order': '198'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '291',
#   'name': 'Huyện Nam Sách',
#   'type': 'Huyện',
#   'province_service_order': '199'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '292',
#   'name': 'Thị xã Kinh Môn',
#   'type': 'Thị xã',
#   'province_service_order': '200'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '293',
#   'name': 'Huyện Kim Thành',
#   'type': 'Huyện',
#   'province_service_order': '201'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '294',
#   'name': 'Huyện Thanh Hà',
#   'type': 'Huyện',
#   'province_service_order': '202'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '295',
#   'name': 'Huyện Cẩm Giàng',
#   'type': 'Huyện',
#   'province_service_order': '203'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '296',
#   'name': 'Huyện Bình Giang',
#   'type': 'Huyện',
#   'province_service_order': '204'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '297',
#   'name': 'Huyện Gia Lộc',
#   'type': 'Huyện',
#   'province_service_order': '205'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '298',
#   'name': 'Huyện Tứ Kỳ',
#   'type': 'Huyện',
#   'province_service_order': '206'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '299',
#   'name': 'Huyện Ninh Giang',
#   'type': 'Huyện',
#   'province_service_order': '207'},
#  {'province_service_key': '30',
#   'province_name': 'Tỉnh Hải Dương',
#   'district_service_key': '300',
#   'name': 'Huyện Thanh Miện',
#   'type': 'Huyện',
#   'province_service_order': '208'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '303',
#   'name': 'Quận Hồng Bàng',
#   'type': 'Quận',
#   'province_service_order': '209'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '304',
#   'name': 'Quận Ngô Quyền',
#   'type': 'Quận',
#   'province_service_order': '210'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '305',
#   'name': 'Quận Lê Chân',
#   'type': 'Quận',
#   'province_service_order': '211'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '306',
#   'name': 'Quận Hải An',
#   'type': 'Quận',
#   'province_service_order': '212'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '307',
#   'name': 'Quận Kiến An',
#   'type': 'Quận',
#   'province_service_order': '213'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '308',
#   'name': 'Quận Đồ Sơn',
#   'type': 'Quận',
#   'province_service_order': '214'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '309',
#   'name': 'Quận Dương Kinh',
#   'type': 'Quận',
#   'province_service_order': '215'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '311',
#   'name': 'Huyện Thuỷ Nguyên',
#   'type': 'Huyện',
#   'province_service_order': '216'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '312',
#   'name': 'Huyện An Dương',
#   'type': 'Huyện',
#   'province_service_order': '217'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '313',
#   'name': 'Huyện An Lão',
#   'type': 'Huyện',
#   'province_service_order': '218'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '314',
#   'name': 'Huyện Kiến Thuỵ',
#   'type': 'Huyện',
#   'province_service_order': '219'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '315',
#   'name': 'Huyện Tiên Lãng',
#   'type': 'Huyện',
#   'province_service_order': '220'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '316',
#   'name': 'Huyện Vĩnh Bảo',
#   'type': 'Huyện',
#   'province_service_order': '221'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '317',
#   'name': 'Huyện Cát Hải',
#   'type': 'Huyện',
#   'province_service_order': '222'},
#  {'province_service_key': '31',
#   'province_name': 'Thành phố Hải Phòng',
#   'district_service_key': '318',
#   'name': 'Huyện Bạch Long Vĩ',
#   'type': 'Huyện',
#   'province_service_order': '223'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '323',
#   'name': 'Thành phố Hưng Yên',
#   'type': 'Thành phố',
#   'province_service_order': '224'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '325',
#   'name': 'Huyện Văn Lâm',
#   'type': 'Huyện',
#   'province_service_order': '225'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '326',
#   'name': 'Huyện Văn Giang',
#   'type': 'Huyện',
#   'province_service_order': '226'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '327',
#   'name': 'Huyện Yên Mỹ',
#   'type': 'Huyện',
#   'province_service_order': '227'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '328',
#   'name': 'Thị xã Mỹ Hào',
#   'type': 'Thị xã',
#   'province_service_order': '228'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '329',
#   'name': 'Huyện Ân Thi',
#   'type': 'Huyện',
#   'province_service_order': '229'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '330',
#   'name': 'Huyện Khoái Châu',
#   'type': 'Huyện',
#   'province_service_order': '230'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '331',
#   'name': 'Huyện Kim Động',
#   'type': 'Huyện',
#   'province_service_order': '231'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '332',
#   'name': 'Huyện Tiên Lữ',
#   'type': 'Huyện',
#   'province_service_order': '232'},
#  {'province_service_key': '33',
#   'province_name': 'Tỉnh Hưng Yên',
#   'district_service_key': '333',
#   'name': 'Huyện Phù Cừ',
#   'type': 'Huyện',
#   'province_service_order': '233'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '336',
#   'name': 'Thành phố Thái Bình',
#   'type': 'Thành phố',
#   'province_service_order': '234'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '338',
#   'name': 'Huyện Quỳnh Phụ',
#   'type': 'Huyện',
#   'province_service_order': '235'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '339',
#   'name': 'Huyện Hưng Hà',
#   'type': 'Huyện',
#   'province_service_order': '236'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '340',
#   'name': 'Huyện Đông Hưng',
#   'type': 'Huyện',
#   'province_service_order': '237'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '341',
#   'name': 'Huyện Thái Thụy',
#   'type': 'Huyện',
#   'province_service_order': '238'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '342',
#   'name': 'Huyện Tiền Hải',
#   'type': 'Huyện',
#   'province_service_order': '239'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '343',
#   'name': 'Huyện Kiến Xương',
#   'type': 'Huyện',
#   'province_service_order': '240'},
#  {'province_service_key': '34',
#   'province_name': 'Tỉnh Thái Bình',
#   'district_service_key': '344',
#   'name': 'Huyện Vũ Thư',
#   'type': 'Huyện',
#   'province_service_order': '241'},
#  {'province_service_key': '35',
#   'province_name': 'Tỉnh Hà Nam',
#   'district_service_key': '347',
#   'name': 'Thành phố Phủ Lý',
#   'type': 'Thành phố',
#   'province_service_order': '242'},
#  {'province_service_key': '35',
#   'province_name': 'Tỉnh Hà Nam',
#   'district_service_key': '349',
#   'name': 'Thị xã Duy Tiên',
#   'type': 'Thị xã',
#   'province_service_order': '243'},
#  {'province_service_key': '35',
#   'province_name': 'Tỉnh Hà Nam',
#   'district_service_key': '350',
#   'name': 'Huyện Kim Bảng',
#   'type': 'Huyện',
#   'province_service_order': '244'},
#  {'province_service_key': '35',
#   'province_name': 'Tỉnh Hà Nam',
#   'district_service_key': '351',
#   'name': 'Huyện Thanh Liêm',
#   'type': 'Huyện',
#   'province_service_order': '245'},
#  {'province_service_key': '35',
#   'province_name': 'Tỉnh Hà Nam',
#   'district_service_key': '352',
#   'name': 'Huyện Bình Lục',
#   'type': 'Huyện',
#   'province_service_order': '246'},
#  {'province_service_key': '35',
#   'province_name': 'Tỉnh Hà Nam',
#   'district_service_key': '353',
#   'name': 'Huyện Lý Nhân',
#   'type': 'Huyện',
#   'province_service_order': '247'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '356',
#   'name': 'Thành phố Nam Định',
#   'type': 'Thành phố',
#   'province_service_order': '248'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '358',
#   'name': 'Huyện Mỹ Lộc',
#   'type': 'Huyện',
#   'province_service_order': '249'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '359',
#   'name': 'Huyện Vụ Bản',
#   'type': 'Huyện',
#   'province_service_order': '250'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '360',
#   'name': 'Huyện Ý Yên',
#   'type': 'Huyện',
#   'province_service_order': '251'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '361',
#   'name': 'Huyện Nghĩa Hưng',
#   'type': 'Huyện',
#   'province_service_order': '252'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '362',
#   'name': 'Huyện Nam Trực',
#   'type': 'Huyện',
#   'province_service_order': '253'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '363',
#   'name': 'Huyện Trực Ninh',
#   'type': 'Huyện',
#   'province_service_order': '254'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '364',
#   'name': 'Huyện Xuân Trường',
#   'type': 'Huyện',
#   'province_service_order': '255'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '365',
#   'name': 'Huyện Giao Thủy',
#   'type': 'Huyện',
#   'province_service_order': '256'},
#  {'province_service_key': '36',
#   'province_name': 'Tỉnh Nam Định',
#   'district_service_key': '366',
#   'name': 'Huyện Hải Hậu',
#   'type': 'Huyện',
#   'province_service_order': '257'},
#  {'province_service_key': '37',
#   'province_name': 'Tỉnh Ninh Bình',
#   'district_service_key': '369',
#   'name': 'Thành phố Ninh Bình',
#   'type': 'Thành phố',
# ...
#   'district_service_key': '860',
#   'name': 'Huyện Tam Bình',
#   'type': 'Huyện',
#   'province_service_order': '619'},
#  {'province_service_key': '86',
#   'province_name': 'Tỉnh Vĩnh Long',
#   'district_service_key': '861',
#   'name': 'Thị xã Bình Minh',
#   'type': 'Thị xã',
#   'province_service_order': '620'},
#  {'province_service_key': '86',
#   'province_name': 'Tỉnh Vĩnh Long',
#   'district_service_key': '862',
#   'name': 'Huyện Trà Ôn',
#   'type': 'Huyện',
#   'province_service_order': '621'},
#  {'province_service_key': '86',
#   'province_name': 'Tỉnh Vĩnh Long',
#   'district_service_key': '863',
#   'name': 'Huyện Bình Tân',
#   'type': 'Huyện',
#   'province_service_order': '622'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '866',
#   'name': 'Thành phố Cao Lãnh',
#   'type': 'Thành phố',
#   'province_service_order': '623'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '867',
#   'name': 'Thành phố Sa Đéc',
#   'type': 'Thành phố',
#   'province_service_order': '624'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '868',
#   'name': 'Thành phố Hồng Ngự',
#   'type': 'Thành phố',
#   'province_service_order': '625'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '869',
#   'name': 'Huyện Tân Hồng',
#   'type': 'Huyện',
#   'province_service_order': '626'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '870',
#   'name': 'Huyện Hồng Ngự',
#   'type': 'Huyện',
#   'province_service_order': '627'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '871',
#   'name': 'Huyện Tam Nông',
#   'type': 'Huyện',
#   'province_service_order': '628'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '872',
#   'name': 'Huyện Tháp Mười',
#   'type': 'Huyện',
#   'province_service_order': '629'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '873',
#   'name': 'Huyện Cao Lãnh',
#   'type': 'Huyện',
#   'province_service_order': '630'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '874',
#   'name': 'Huyện Thanh Bình',
#   'type': 'Huyện',
#   'province_service_order': '631'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '875',
#   'name': 'Huyện Lấp Vò',
#   'type': 'Huyện',
#   'province_service_order': '632'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '876',
#   'name': 'Huyện Lai Vung',
#   'type': 'Huyện',
#   'province_service_order': '633'},
#  {'province_service_key': '87',
#   'province_name': 'Tỉnh Đồng Tháp',
#   'district_service_key': '877',
#   'name': 'Huyện Châu Thành',
#   'type': 'Huyện',
#   'province_service_order': '634'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '883',
#   'name': 'Thành phố Long Xuyên',
#   'type': 'Thành phố',
#   'province_service_order': '635'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '884',
#   'name': 'Thành phố Châu Đốc',
#   'type': 'Thành phố',
#   'province_service_order': '636'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '886',
#   'name': 'Huyện An Phú',
#   'type': 'Huyện',
#   'province_service_order': '637'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '887',
#   'name': 'Thị xã Tân Châu',
#   'type': 'Thị xã',
#   'province_service_order': '638'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '888',
#   'name': 'Huyện Phú Tân',
#   'type': 'Huyện',
#   'province_service_order': '639'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '889',
#   'name': 'Huyện Châu Phú',
#   'type': 'Huyện',
#   'province_service_order': '640'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '890',
#   'name': 'Huyện Tịnh Biên',
#   'type': 'Huyện',
#   'province_service_order': '641'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '891',
#   'name': 'Huyện Tri Tôn',
#   'type': 'Huyện',
#   'province_service_order': '642'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '892',
#   'name': 'Huyện Châu Thành',
#   'type': 'Huyện',
#   'province_service_order': '643'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '893',
#   'name': 'Huyện Chợ Mới',
#   'type': 'Huyện',
#   'province_service_order': '644'},
#  {'province_service_key': '89',
#   'province_name': 'Tỉnh An Giang',
#   'district_service_key': '894',
#   'name': 'Huyện Thoại Sơn',
#   'type': 'Huyện',
#   'province_service_order': '645'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '899',
#   'name': 'Thành phố Rạch Giá',
#   'type': 'Thành phố',
#   'province_service_order': '646'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '900',
#   'name': 'Thành phố Hà Tiên',
#   'type': 'Thành phố',
#   'province_service_order': '647'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '902',
#   'name': 'Huyện Kiên Lương',
#   'type': 'Huyện',
#   'province_service_order': '648'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '903',
#   'name': 'Huyện Hòn Đất',
#   'type': 'Huyện',
#   'province_service_order': '649'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '904',
#   'name': 'Huyện Tân Hiệp',
#   'type': 'Huyện',
#   'province_service_order': '650'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '905',
#   'name': 'Huyện Châu Thành',
#   'type': 'Huyện',
#   'province_service_order': '651'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '906',
#   'name': 'Huyện Giồng Riềng',
#   'type': 'Huyện',
#   'province_service_order': '652'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '907',
#   'name': 'Huyện Gò Quao',
#   'type': 'Huyện',
#   'province_service_order': '653'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '908',
#   'name': 'Huyện An Biên',
#   'type': 'Huyện',
#   'province_service_order': '654'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '909',
#   'name': 'Huyện An Minh',
#   'type': 'Huyện',
#   'province_service_order': '655'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '910',
#   'name': 'Huyện Vĩnh Thuận',
#   'type': 'Huyện',
#   'province_service_order': '656'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '911',
#   'name': 'Thành phố Phú Quốc',
#   'type': 'Thành phố',
#   'province_service_order': '657'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '912',
#   'name': 'Huyện Kiên Hải',
#   'type': 'Huyện',
#   'province_service_order': '658'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '913',
#   'name': 'Huyện U Minh Thượng',
#   'type': 'Huyện',
#   'province_service_order': '659'},
#  {'province_service_key': '91',
#   'province_name': 'Tỉnh Kiên Giang',
#   'district_service_key': '914',
#   'name': 'Huyện Giang Thành',
#   'type': 'Huyện',
#   'province_service_order': '660'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '916',
#   'name': 'Quận Ninh Kiều',
#   'type': 'Quận',
#   'province_service_order': '661'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '917',
#   'name': 'Quận Ô Môn',
#   'type': 'Quận',
#   'province_service_order': '662'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '918',
#   'name': 'Quận Bình Thuỷ',
#   'type': 'Quận',
#   'province_service_order': '663'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '919',
#   'name': 'Quận Cái Răng',
#   'type': 'Quận',
#   'province_service_order': '664'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '923',
#   'name': 'Quận Thốt Nốt',
#   'type': 'Quận',
#   'province_service_order': '665'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '924',
#   'name': 'Huyện Vĩnh Thạnh',
#   'type': 'Huyện',
#   'province_service_order': '666'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '925',
#   'name': 'Huyện Cờ Đỏ',
#   'type': 'Huyện',
#   'province_service_order': '667'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '926',
#   'name': 'Huyện Phong Điền',
#   'type': 'Huyện',
#   'province_service_order': '668'},
#  {'province_service_key': '92',
#   'province_name': 'Thành phố Cần Thơ',
#   'district_service_key': '927',
#   'name': 'Huyện Thới Lai',
#   'type': 'Huyện',
#   'province_service_order': '669'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '930',
#   'name': 'Thành phố Vị Thanh',
#   'type': 'Thành phố',
#   'province_service_order': '670'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '931',
#   'name': 'Thành phố Ngã Bảy',
#   'type': 'Thành phố',
#   'province_service_order': '671'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '932',
#   'name': 'Huyện Châu Thành A',
#   'type': 'Huyện',
#   'province_service_order': '672'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '933',
#   'name': 'Huyện Châu Thành',
#   'type': 'Huyện',
#   'province_service_order': '673'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '934',
#   'name': 'Huyện Phụng Hiệp',
#   'type': 'Huyện',
#   'province_service_order': '674'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '935',
#   'name': 'Huyện Vị Thuỷ',
#   'type': 'Huyện',
#   'province_service_order': '675'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '936',
#   'name': 'Huyện Long Mỹ',
#   'type': 'Huyện',
#   'province_service_order': '676'},
#  {'province_service_key': '93',
#   'province_name': 'Tỉnh Hậu Giang',
#   'district_service_key': '937',
#   'name': 'Thị xã Long Mỹ',
#   'type': 'Thị xã',
#   'province_service_order': '677'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '941',
#   'name': 'Thành phố Sóc Trăng',
#   'type': 'Thành phố',
#   'province_service_order': '678'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '942',
#   'name': 'Huyện Châu Thành',
#   'type': 'Huyện',
#   'province_service_order': '679'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '943',
#   'name': 'Huyện Kế Sách',
#   'type': 'Huyện',
#   'province_service_order': '680'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '944',
#   'name': 'Huyện Mỹ Tú',
#   'type': 'Huyện',
#   'province_service_order': '681'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '945',
#   'name': 'Huyện Cù Lao Dung',
#   'type': 'Huyện',
#   'province_service_order': '682'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '946',
#   'name': 'Huyện Long Phú',
#   'type': 'Huyện',
#   'province_service_order': '683'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '947',
#   'name': 'Huyện Mỹ Xuyên',
#   'type': 'Huyện',
#   'province_service_order': '684'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '948',
#   'name': 'Thị xã Ngã Năm',
#   'type': 'Thị xã',
#   'province_service_order': '685'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '949',
#   'name': 'Huyện Thạnh Trị',
#   'type': 'Huyện',
#   'province_service_order': '686'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '950',
#   'name': 'Thị xã Vĩnh Châu',
#   'type': 'Thị xã',
#   'province_service_order': '687'},
#  {'province_service_key': '94',
#   'province_name': 'Tỉnh Sóc Trăng',
#   'district_service_key': '951',
#   'name': 'Huyện Trần Đề',
#   'type': 'Huyện',
#   'province_service_order': '688'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '954',
#   'name': 'Thành phố Bạc Liêu',
#   'type': 'Thành phố',
#   'province_service_order': '689'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '956',
#   'name': 'Huyện Hồng Dân',
#   'type': 'Huyện',
#   'province_service_order': '690'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '957',
#   'name': 'Huyện Phước Long',
#   'type': 'Huyện',
#   'province_service_order': '691'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '958',
#   'name': 'Huyện Vĩnh Lợi',
#   'type': 'Huyện',
#   'province_service_order': '692'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '959',
#   'name': 'Thị xã Giá Rai',
#   'type': 'Thị xã',
#   'province_service_order': '693'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '960',
#   'name': 'Huyện Đông Hải',
#   'type': 'Huyện',
#   'province_service_order': '694'},
#  {'province_service_key': '95',
#   'province_name': 'Tỉnh Bạc Liêu',
#   'district_service_key': '961',
#   'name': 'Huyện Hoà Bình',
#   'type': 'Huyện',
#   'province_service_order': '695'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '964',
#   'name': 'Thành phố Cà Mau',
#   'type': 'Thành phố',
#   'province_service_order': '696'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '966',
#   'name': 'Huyện U Minh',
#   'type': 'Huyện',
#   'province_service_order': '697'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '967',
#   'name': 'Huyện Thới Bình',
#   'type': 'Huyện',
#   'province_service_order': '698'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '968',
#   'name': 'Huyện Trần Văn Thời',
#   'type': 'Huyện',
#   'province_service_order': '699'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '969',
#   'name': 'Huyện Cái Nước',
#   'type': 'Huyện',
#   'province_service_order': '700'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '970',
#   'name': 'Huyện Đầm Dơi',
#   'type': 'Huyện',
#   'province_service_order': '701'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '971',
#   'name': 'Huyện Năm Căn',
#   'type': 'Huyện',
#   'province_service_order': '702'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '972',
#   'name': 'Huyện Phú Tân',
#   'type': 'Huyện',
#   'province_service_order': '703'},
#  {'province_service_key': '96',
#   'province_name': 'Tỉnh Cà Mau',
#   'district_service_key': '973',
#   'name': 'Huyện Ngọc Hiển',
#   'type': 'Huyện',
#   'province_service_order': '704'}]
